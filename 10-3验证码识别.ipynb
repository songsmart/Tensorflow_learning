# %%
# coding: utf-8


import os
import sys
sys.path.append("F:\yjs2019\Tensorflow_learn\nets")
import tensorflow as tf 
from PIL import Image
from nets import nets_factory
import numpy as np



# 不同字符数量
CHAR_SET_LEN = 10
# 图片高度
IMAGE_HEIGHT = 60 
# 图片宽度
IMAGE_WIDTH = 160  
# 批次
BATCH_SIZE = 25
# tfrecord文件存放路径
TFRECORD_FILE = "./captcha/train.tfrecords"

# placeholder
x = tf.placeholder(tf.float32, [None, 224, 224])  
y0 = tf.placeholder(tf.float32, [None]) 
y1 = tf.placeholder(tf.float32, [None]) 
y2 = tf.placeholder(tf.float32, [None]) 
y3 = tf.placeholder(tf.float32, [None])

# 学习率
lr = tf.Variable(0.003, dtype=tf.float32)

# 从tfrecord读出数据
def read_and_decode(filename):
    # 根据文件名生成一个队列
    filename_queue = tf.train.string_input_producer([filename])
    reader = tf.TFRecordReader()
    # 返回文件名和文件
    _, serialized_example = reader.read(filename_queue)   
    features = tf.parse_single_example(serialized_example,
                                       features={
                                           'image' : tf.FixedLenFeature([], tf.string),
                                           'label0': tf.FixedLenFeature([], tf.int64),
                                           'label1': tf.FixedLenFeature([], tf.int64),
                                           'label2': tf.FixedLenFeature([], tf.int64),
                                           'label3': tf.FixedLenFeature([], tf.int64),
                                       })
    # 获取图片数据
    image = tf.decode_raw(features['image'], tf.uint8)
    # tf.train.shuffle_batch必须确定shape
    image = tf.reshape(image, [224, 224])
    # 图片预处理
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.subtract(image, 0.5)
    image = tf.multiply(image, 2.0)
    # 获取label
    label0 = tf.cast(features['label0'], tf.int32)
    label1 = tf.cast(features['label1'], tf.int32)
    label2 = tf.cast(features['label2'], tf.int32)
    label3 = tf.cast(features['label3'], tf.int32)

    return image, label0, label1, label2, label3



# 获取图片数据和标签
image, label0, label1, label2, label3 = read_and_decode(TFRECORD_FILE)

# 使用shuffle_batch可以随机打乱
image_batch, label_batch0, label_batch1, label_batch2, label_batch3 = tf.train.shuffle_batch(
        [image, label0, label1, label2, label3], batch_size=BATCH_SIZE,
        capacity = 50000, min_after_dequeue=10000, num_threads=1)

# 定义网络结构
train_network_fn = nets_factory.get_network_fn(
    'alexnet_v2',
    num_classes=CHAR_SET_LEN,
    weight_decay=0.0005,
    is_training=True)
 
    
with tf.Session() as sess:
    # inputs: a tensor of size [batch_size, height, width, channels]
    X = tf.reshape(x, [BATCH_SIZE, 224, 224, 1])
    # 数据输入网络得到输出值
    logits0, logits1, logits2, logits3, end_points = train_network_fn(X)
    
    # 把标签转成one_hot的形式
    one_hot_labels0 = tf.one_hot(indices=tf.cast(y0, tf.int32), depth=CHAR_SET_LEN)
    one_hot_labels1 = tf.one_hot(indices=tf.cast(y1, tf.int32), depth=CHAR_SET_LEN)
    one_hot_labels2 = tf.one_hot(indices=tf.cast(y2, tf.int32), depth=CHAR_SET_LEN)
    one_hot_labels3 = tf.one_hot(indices=tf.cast(y3, tf.int32), depth=CHAR_SET_LEN)
    
    # 计算loss
    loss0 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits0,labels=one_hot_labels0)) 
    loss1 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits1,labels=one_hot_labels1)) 
    loss2 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits2,labels=one_hot_labels2)) 
    loss3 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits3,labels=one_hot_labels3)) 
    # 计算总的loss
    total_loss = (loss0+loss1+loss2+loss3)/4.0
    # 优化total_loss
    optimizer = tf.train.AdamOptimizer(learning_rate=lr).minimize(total_loss) 
    
    # 计算准确率
    correct_prediction0 = tf.equal(tf.argmax(one_hot_labels0,1),tf.argmax(logits0,1))
    accuracy0 = tf.reduce_mean(tf.cast(correct_prediction0,tf.float32))
    
    correct_prediction1 = tf.equal(tf.argmax(one_hot_labels1,1),tf.argmax(logits1,1))
    accuracy1 = tf.reduce_mean(tf.cast(correct_prediction1,tf.float32))
    
    correct_prediction2 = tf.equal(tf.argmax(one_hot_labels2,1),tf.argmax(logits2,1))
    accuracy2 = tf.reduce_mean(tf.cast(correct_prediction2,tf.float32))
    
    correct_prediction3 = tf.equal(tf.argmax(one_hot_labels3,1),tf.argmax(logits3,1))
    accuracy3 = tf.reduce_mean(tf.cast(correct_prediction3,tf.float32)) 
    
    # 用于保存模型
    saver = tf.train.Saver()
    # 初始化
    sess.run(tf.global_variables_initializer())
    
    # 创建一个协调器，管理线程
    coord = tf.train.Coordinator()
    # 启动QueueRunner, 此时文件名队列已经进队
    threads = tf.train.start_queue_runners(sess=sess, coord=coord)

    for i in range(6001):
        # 获取一个批次的数据和标签
        b_image, b_label0, b_label1 ,b_label2 ,b_label3 = sess.run([image_batch, label_batch0, label_batch1, label_batch2, label_batch3])
        # 优化模型
        sess.run(optimizer, feed_dict={x: b_image, y0:b_label0, y1: b_label1, y2: b_label2, y3: b_label3})  

        # 每迭代20次计算一次loss和准确率  
        if i % 20 == 0:  
            # 每迭代2000次降低一次学习率
            if i%2000 == 0:
                sess.run(tf.assign(lr, lr/3))
            acc0, acc1, acc2, acc3, loss_ = sess.run([accuracy0, accuracy1, accuracy2, accuracy3, total_loss],
                                                     feed_dict={x: b_image,
                                                                y0: b_label0,
                                                                y1: b_label1,
                                                                y2: b_label2,
                                                                y3: b_label3})
            learning_rate = sess.run(lr)
            print("Iter:%d  Loss:%.3f  Accuracy:%.2f,%.2f,%.2f,%.2f  Learning_rate:%.4f" % (i,
                                                                                             loss_,
                                                                                             acc0,
                                                                                             acc1,
                                                                                             acc2,
                                                                                             acc3,
                                                                                             learning_rate))
             
            # 保存模型
            # if acc0 > 0.90 and acc1 > 0.90 and acc2 > 0.90 and acc3 > 0.90: 
            if i==6000:
                saver.save(sess, "./captcha/models/crack_captcha.model", global_step=i)  
                break 
                
    # 通知其他线程关闭
    coord.request_stop()
    # 其他所有线程关闭之后，这一函数才能返回
    coord.join(threads)
# Out:
# D:\anaconda\Anaconda\envs\tensorflow\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# D:\anaconda\Anaconda\envs\tensorflow\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# D:\anaconda\Anaconda\envs\tensorflow\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)
# D:\anaconda\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:469: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\anaconda\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:470: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\anaconda\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:471: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\anaconda\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:472: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\anaconda\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:473: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\anaconda\Anaconda\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:476: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Iter:0  Loss:2893.888  Accuracy:0.20,0.20,0.16,0.20  Learning_rate:0.0010
# Iter:20  Loss:2.298  Accuracy:0.00,0.20,0.00,0.04  Learning_rate:0.0010
# Iter:40  Loss:2.304  Accuracy:0.04,0.12,0.04,0.16  Learning_rate:0.0010
# Iter:60  Loss:2.306  Accuracy:0.08,0.16,0.04,0.24  Learning_rate:0.0010
# Iter:80  Loss:2.284  Accuracy:0.08,0.08,0.20,0.16  Learning_rate:0.0010
# Iter:100  Loss:2.301  Accuracy:0.08,0.12,0.08,0.28  Learning_rate:0.0010
# Iter:120  Loss:2.311  Accuracy:0.12,0.00,0.08,0.04  Learning_rate:0.0010
# Iter:140  Loss:2.327  Accuracy:0.04,0.08,0.12,0.04  Learning_rate:0.0010
# Iter:160  Loss:2.303  Accuracy:0.12,0.16,0.12,0.12  Learning_rate:0.0010
# Iter:180  Loss:2.277  Accuracy:0.16,0.08,0.28,0.04  Learning_rate:0.0010
# Iter:200  Loss:2.308  Accuracy:0.08,0.04,0.12,0.16  Learning_rate:0.0010
# Iter:220  Loss:2.312  Accuracy:0.08,0.12,0.04,0.04  Learning_rate:0.0010
# Iter:240  Loss:2.333  Accuracy:0.08,0.12,0.08,0.16  Learning_rate:0.0010
# Iter:260  Loss:2.300  Accuracy:0.16,0.08,0.20,0.08  Learning_rate:0.0010
# Iter:280  Loss:2.293  Accuracy:0.00,0.16,0.08,0.16  Learning_rate:0.0010
# Iter:300  Loss:2.314  Accuracy:0.00,0.04,0.04,0.12  Learning_rate:0.0010
# Iter:320  Loss:2.301  Accuracy:0.16,0.12,0.12,0.16  Learning_rate:0.0010
# Iter:340  Loss:2.285  Accuracy:0.04,0.12,0.20,0.12  Learning_rate:0.0010
# Iter:360  Loss:2.235  Accuracy:0.20,0.16,0.28,0.24  Learning_rate:0.0010
# Iter:380  Loss:2.255  Accuracy:0.28,0.12,0.24,0.16  Learning_rate:0.0010
# Iter:400  Loss:2.233  Accuracy:0.24,0.20,0.08,0.24  Learning_rate:0.0010
# Iter:420  Loss:2.271  Accuracy:0.00,0.24,0.24,0.28  Learning_rate:0.0010
# Iter:440  Loss:2.193  Accuracy:0.20,0.24,0.00,0.16  Learning_rate:0.0010
# Iter:460  Loss:2.214  Accuracy:0.32,0.08,0.24,0.24  Learning_rate:0.0010
# Iter:480  Loss:2.154  Accuracy:0.36,0.12,0.08,0.20  Learning_rate:0.0010
# Iter:500  Loss:2.120  Accuracy:0.28,0.32,0.12,0.16  Learning_rate:0.0010
# Iter:520  Loss:2.084  Accuracy:0.16,0.28,0.20,0.24  Learning_rate:0.0010
# Iter:540  Loss:2.009  Accuracy:0.56,0.36,0.20,0.12  Learning_rate:0.0010
# Iter:560  Loss:1.882  Accuracy:0.44,0.44,0.28,0.24  Learning_rate:0.0010
# Iter:580  Loss:1.965  Accuracy:0.44,0.16,0.20,0.20  Learning_rate:0.0010
# Iter:600  Loss:1.957  Accuracy:0.12,0.24,0.32,0.32  Learning_rate:0.0010
# Iter:620  Loss:1.969  Accuracy:0.32,0.24,0.28,0.24  Learning_rate:0.0010
# Iter:640  Loss:1.908  Accuracy:0.44,0.24,0.20,0.44  Learning_rate:0.0010
# Iter:660  Loss:1.881  Accuracy:0.32,0.20,0.40,0.36  Learning_rate:0.0010
# Iter:680  Loss:1.869  Accuracy:0.28,0.28,0.20,0.24  Learning_rate:0.0010
# Iter:700  Loss:1.861  Accuracy:0.44,0.32,0.36,0.32  Learning_rate:0.0010
# Iter:720  Loss:1.750  Accuracy:0.48,0.24,0.32,0.52  Learning_rate:0.0010
# Iter:740  Loss:1.653  Accuracy:0.64,0.24,0.28,0.40  Learning_rate:0.0010
# Iter:760  Loss:1.657  Accuracy:0.44,0.40,0.28,0.40  Learning_rate:0.0010
# Iter:780  Loss:1.702  Accuracy:0.52,0.32,0.28,0.36  Learning_rate:0.0010
# Iter:800  Loss:1.544  Accuracy:0.64,0.32,0.52,0.40  Learning_rate:0.0010
# Iter:820  Loss:1.589  Accuracy:0.48,0.28,0.32,0.44  Learning_rate:0.0010
# Iter:840  Loss:1.699  Accuracy:0.56,0.44,0.32,0.44  Learning_rate:0.0010
# Iter:860  Loss:1.568  Accuracy:0.60,0.24,0.40,0.40  Learning_rate:0.0010
# Iter:880  Loss:1.227  Accuracy:0.60,0.52,0.32,0.72  Learning_rate:0.0010
# Iter:900  Loss:1.223  Accuracy:0.76,0.44,0.44,0.56  Learning_rate:0.0010
# Iter:920  Loss:1.439  Accuracy:0.64,0.36,0.32,0.72  Learning_rate:0.0010
# Iter:940  Loss:1.269  Accuracy:0.84,0.40,0.36,0.60  Learning_rate:0.0010
# Iter:960  Loss:1.438  Accuracy:0.64,0.52,0.40,0.44  Learning_rate:0.0010
# Iter:980  Loss:1.453  Accuracy:0.68,0.52,0.40,0.56  Learning_rate:0.0010
# Iter:1000  Loss:1.265  Accuracy:0.60,0.56,0.32,0.56  Learning_rate:0.0010
# Iter:1020  Loss:1.140  Accuracy:0.76,0.52,0.52,0.64  Learning_rate:0.0010
# Iter:1040  Loss:1.267  Accuracy:0.56,0.44,0.16,0.60  Learning_rate:0.0010
# Iter:1060  Loss:1.077  Accuracy:0.76,0.56,0.48,0.64  Learning_rate:0.0010
# Iter:1080  Loss:1.215  Accuracy:0.60,0.40,0.40,0.60  Learning_rate:0.0010
# Iter:1100  Loss:1.203  Accuracy:0.68,0.48,0.36,0.60  Learning_rate:0.0010
# Iter:1120  Loss:1.005  Accuracy:0.80,0.72,0.56,0.64  Learning_rate:0.0010
# Iter:1140  Loss:1.079  Accuracy:0.60,0.60,0.56,0.80  Learning_rate:0.0010
# Iter:1160  Loss:1.008  Accuracy:0.76,0.68,0.44,0.68  Learning_rate:0.0010
# Iter:1180  Loss:0.972  Accuracy:0.88,0.60,0.56,0.60  Learning_rate:0.0010
# Iter:1200  Loss:1.062  Accuracy:0.88,0.36,0.60,0.76  Learning_rate:0.0010
# Iter:1220  Loss:0.873  Accuracy:0.84,0.60,0.52,0.88  Learning_rate:0.0010
# Iter:1240  Loss:1.006  Accuracy:0.72,0.88,0.64,0.56  Learning_rate:0.0010
# Iter:1260  Loss:0.954  Accuracy:0.72,0.68,0.60,0.64  Learning_rate:0.0010
# Iter:1280  Loss:0.920  Accuracy:0.76,0.60,0.60,0.72  Learning_rate:0.0010
# Iter:1300  Loss:0.914  Accuracy:0.56,0.52,0.64,0.72  Learning_rate:0.0010
# Iter:1320  Loss:0.774  Accuracy:0.76,0.76,0.56,0.84  Learning_rate:0.0010
# Iter:1340  Loss:1.035  Accuracy:0.68,0.60,0.52,0.64  Learning_rate:0.0010
# Iter:1360  Loss:1.066  Accuracy:0.72,0.56,0.40,0.60  Learning_rate:0.0010
# Iter:1380  Loss:0.814  Accuracy:0.84,0.64,0.72,0.64  Learning_rate:0.0010
# Iter:1400  Loss:0.710  Accuracy:0.92,0.60,0.64,0.80  Learning_rate:0.0010
# Iter:1420  Loss:0.825  Accuracy:0.72,0.72,0.68,0.84  Learning_rate:0.0010
# Iter:1440  Loss:0.703  Accuracy:0.88,0.64,0.64,0.80  Learning_rate:0.0010
# Iter:1460  Loss:0.884  Accuracy:0.68,0.48,0.76,0.72  Learning_rate:0.0010
# Iter:1480  Loss:0.807  Accuracy:0.72,0.64,0.60,0.72  Learning_rate:0.0010
# Iter:1500  Loss:0.657  Accuracy:0.76,0.76,0.72,0.84  Learning_rate:0.0010
# Iter:1520  Loss:0.825  Accuracy:0.88,0.80,0.72,0.72  Learning_rate:0.0010
# Iter:1540  Loss:0.503  Accuracy:0.88,0.84,0.76,0.96  Learning_rate:0.0010
# Iter:1560  Loss:0.673  Accuracy:0.92,0.72,0.60,0.80  Learning_rate:0.0010
# Iter:1580  Loss:0.720  Accuracy:0.92,0.72,0.68,0.64  Learning_rate:0.0010
# Iter:1600  Loss:0.714  Accuracy:0.80,0.68,0.72,0.88  Learning_rate:0.0010
# Iter:1620  Loss:0.590  Accuracy:0.84,0.76,0.60,0.88  Learning_rate:0.0010
# Iter:1640  Loss:0.601  Accuracy:0.76,0.80,0.64,0.84  Learning_rate:0.0010
# Iter:1660  Loss:0.654  Accuracy:0.76,0.72,0.68,0.80  Learning_rate:0.0010
# Iter:1680  Loss:0.794  Accuracy:0.88,0.72,0.64,0.64  Learning_rate:0.0010
# Iter:1700  Loss:0.525  Accuracy:0.92,0.88,0.76,0.92  Learning_rate:0.0010
# Iter:1720  Loss:0.646  Accuracy:0.80,0.76,0.64,0.76  Learning_rate:0.0010
# Iter:1740  Loss:0.525  Accuracy:0.80,0.76,0.80,0.92  Learning_rate:0.0010
# Iter:1760  Loss:0.547  Accuracy:0.84,0.84,0.76,0.80  Learning_rate:0.0010
# Iter:1780  Loss:0.765  Accuracy:0.76,0.76,0.68,0.76  Learning_rate:0.0010
# Iter:1800  Loss:0.611  Accuracy:0.92,0.72,0.64,0.76  Learning_rate:0.0010
# Iter:1820  Loss:0.448  Accuracy:0.88,0.72,0.72,0.84  Learning_rate:0.0010
# Iter:1840  Loss:0.601  Accuracy:0.96,0.76,0.60,0.88  Learning_rate:0.0010
# Iter:1860  Loss:0.522  Accuracy:0.76,0.80,0.84,0.88  Learning_rate:0.0010
# Iter:1880  Loss:0.554  Accuracy:0.92,0.80,0.76,0.88  Learning_rate:0.0010
# Iter:1900  Loss:0.444  Accuracy:1.00,0.68,0.76,0.92  Learning_rate:0.0010
# Iter:1920  Loss:0.567  Accuracy:0.84,0.64,0.80,0.80  Learning_rate:0.0010
# Iter:1940  Loss:0.603  Accuracy:0.84,0.84,0.72,0.84  Learning_rate:0.0010
# Iter:1960  Loss:0.540  Accuracy:0.92,0.76,0.72,0.80  Learning_rate:0.0010
# Iter:1980  Loss:0.367  Accuracy:0.88,0.84,0.88,0.84  Learning_rate:0.0010
# Iter:2000  Loss:0.367  Accuracy:0.80,0.96,0.92,0.96  Learning_rate:0.0003
# Iter:2020  Loss:0.367  Accuracy:0.96,0.92,0.80,0.76  Learning_rate:0.0003
# Iter:2040  Loss:0.400  Accuracy:0.96,0.84,0.80,0.88  Learning_rate:0.0003
# Iter:2060  Loss:0.321  Accuracy:0.92,0.88,0.88,0.88  Learning_rate:0.0003
# Iter:2080  Loss:0.513  Accuracy:0.92,0.76,0.80,0.84  Learning_rate:0.0003
# Iter:2100  Loss:0.372  Accuracy:0.92,0.80,0.72,0.96  Learning_rate:0.0003
# Iter:2120  Loss:0.359  Accuracy:0.92,0.80,0.84,0.88  Learning_rate:0.0003
# Iter:2140  Loss:0.306  Accuracy:0.96,0.92,0.84,0.84  Learning_rate:0.0003
# Iter:2160  Loss:0.442  Accuracy:0.88,0.92,0.80,0.92  Learning_rate:0.0003
# Iter:2180  Loss:0.328  Accuracy:0.96,0.72,0.92,0.88  Learning_rate:0.0003
# Iter:2200  Loss:0.257  Accuracy:1.00,0.88,0.88,0.88  Learning_rate:0.0003
# Iter:2220  Loss:0.533  Accuracy:0.92,0.80,0.76,0.88  Learning_rate:0.0003
# Iter:2240  Loss:0.253  Accuracy:0.88,0.92,0.92,0.96  Learning_rate:0.0003
# Iter:2260  Loss:0.342  Accuracy:0.84,0.84,0.96,0.96  Learning_rate:0.0003
# Iter:2280  Loss:0.299  Accuracy:0.84,0.88,0.84,0.88  Learning_rate:0.0003
# Iter:2300  Loss:0.481  Accuracy:0.92,0.88,0.76,0.80  Learning_rate:0.0003
# Iter:2320  Loss:0.401  Accuracy:0.96,0.76,0.80,0.92  Learning_rate:0.0003
# Iter:2340  Loss:0.480  Accuracy:0.84,0.76,0.80,0.92  Learning_rate:0.0003
# Iter:2360  Loss:0.359  Accuracy:0.88,0.84,0.84,0.96  Learning_rate:0.0003
# Iter:2380  Loss:0.339  Accuracy:0.92,0.80,0.92,0.92  Learning_rate:0.0003
# Iter:2400  Loss:0.248  Accuracy:1.00,0.84,1.00,0.88  Learning_rate:0.0003
# Iter:2420  Loss:0.436  Accuracy:0.84,0.72,0.80,0.88  Learning_rate:0.0003
# Iter:2440  Loss:0.409  Accuracy:0.88,0.88,0.88,0.88  Learning_rate:0.0003
# Iter:2460  Loss:0.264  Accuracy:0.96,0.88,0.80,0.96  Learning_rate:0.0003
# Iter:2480  Loss:0.411  Accuracy:0.96,0.92,0.68,0.80  Learning_rate:0.0003
# Iter:2500  Loss:0.359  Accuracy:0.88,0.88,0.92,0.84  Learning_rate:0.0003
# Iter:2520  Loss:0.328  Accuracy:1.00,0.80,0.80,0.92  Learning_rate:0.0003
# Iter:2540  Loss:0.379  Accuracy:0.96,0.84,0.76,0.92  Learning_rate:0.0003
# Iter:2560  Loss:0.201  Accuracy:1.00,0.76,0.96,0.96  Learning_rate:0.0003
# Iter:2580  Loss:0.241  Accuracy:0.92,0.80,0.96,0.96  Learning_rate:0.0003
# Iter:2600  Loss:0.338  Accuracy:0.92,1.00,0.88,0.72  Learning_rate:0.0003
# Iter:2620  Loss:0.165  Accuracy:0.96,1.00,0.80,0.96  Learning_rate:0.0003
# Iter:2640  Loss:0.401  Accuracy:0.84,0.84,0.92,0.80  Learning_rate:0.0003
# Iter:2660  Loss:0.372  Accuracy:0.92,0.92,0.76,0.76  Learning_rate:0.0003
# Iter:2680  Loss:0.232  Accuracy:0.96,0.92,0.92,0.88  Learning_rate:0.0003
# Iter:2700  Loss:0.231  Accuracy:0.96,0.88,0.92,1.00  Learning_rate:0.0003
# Iter:2720  Loss:0.234  Accuracy:1.00,0.96,0.84,0.88  Learning_rate:0.0003
# Iter:2740  Loss:0.393  Accuracy:0.92,0.84,0.68,0.92  Learning_rate:0.0003
# Iter:2760  Loss:0.307  Accuracy:0.92,0.88,0.80,0.92  Learning_rate:0.0003
# Iter:2780  Loss:0.214  Accuracy:0.96,0.88,0.80,1.00  Learning_rate:0.0003
# Iter:2800  Loss:0.171  Accuracy:1.00,0.84,0.92,1.00  Learning_rate:0.0003
# Iter:2820  Loss:0.248  Accuracy:0.96,0.84,0.88,0.92  Learning_rate:0.0003
# Iter:2840  Loss:0.199  Accuracy:0.88,1.00,0.92,0.96  Learning_rate:0.0003
# Iter:2860  Loss:0.150  Accuracy:1.00,0.96,0.92,0.96  Learning_rate:0.0003
# Iter:2880  Loss:0.184  Accuracy:0.88,0.96,0.96,0.96  Learning_rate:0.0003
# Iter:2900  Loss:0.121  Accuracy:1.00,1.00,0.96,0.96  Learning_rate:0.0003
# Iter:2920  Loss:0.320  Accuracy:0.96,0.96,0.84,0.88  Learning_rate:0.0003
# Iter:2940  Loss:0.289  Accuracy:0.84,0.96,0.88,0.92  Learning_rate:0.0003
# Iter:2960  Loss:0.191  Accuracy:0.92,0.88,0.88,1.00  Learning_rate:0.0003
# Iter:2980  Loss:0.282  Accuracy:0.92,0.92,0.88,0.84  Learning_rate:0.0003
# Iter:3000  Loss:0.300  Accuracy:0.92,0.88,0.84,0.96  Learning_rate:0.0003
# Iter:3020  Loss:0.287  Accuracy:0.96,0.96,0.96,0.80  Learning_rate:0.0003
# Iter:3040  Loss:0.176  Accuracy:1.00,0.84,0.92,0.92  Learning_rate:0.0003
# Iter:3060  Loss:0.209  Accuracy:1.00,0.88,0.80,0.92  Learning_rate:0.0003
# Iter:3080  Loss:0.153  Accuracy:0.96,0.88,0.92,0.96  Learning_rate:0.0003
# Iter:3100  Loss:0.145  Accuracy:1.00,0.88,0.96,0.96  Learning_rate:0.0003
# Iter:3120  Loss:0.235  Accuracy:0.88,0.96,0.88,0.92  Learning_rate:0.0003
# Iter:3140  Loss:0.219  Accuracy:0.88,0.92,0.96,0.92  Learning_rate:0.0003
# Iter:3160  Loss:0.326  Accuracy:0.80,0.88,0.88,0.96  Learning_rate:0.0003
# Iter:3180  Loss:0.224  Accuracy:0.92,0.84,0.76,1.00  Learning_rate:0.0003
# Iter:3200  Loss:0.201  Accuracy:0.88,0.92,0.96,1.00  Learning_rate:0.0003
# Iter:3220  Loss:0.194  Accuracy:0.92,0.88,0.92,0.88  Learning_rate:0.0003
# Iter:3240  Loss:0.146  Accuracy:0.92,0.88,1.00,0.96  Learning_rate:0.0003
# Iter:3260  Loss:0.245  Accuracy:0.96,0.84,0.76,1.00  Learning_rate:0.0003
# Iter:3280  Loss:0.161  Accuracy:0.92,0.92,0.88,0.96  Learning_rate:0.0003
# Iter:3300  Loss:0.165  Accuracy:0.96,0.88,0.96,1.00  Learning_rate:0.0003
# Iter:3320  Loss:0.203  Accuracy:0.96,0.88,0.88,0.96  Learning_rate:0.0003
# Iter:3340  Loss:0.082  Accuracy:0.96,0.96,1.00,1.00  Learning_rate:0.0003
# Iter:3360  Loss:0.251  Accuracy:0.96,0.96,0.80,0.88  Learning_rate:0.0003
# Iter:3380  Loss:0.172  Accuracy:0.96,0.96,0.84,0.92  Learning_rate:0.0003
# Iter:3400  Loss:0.119  Accuracy:1.00,1.00,0.92,0.92  Learning_rate:0.0003
# Iter:3420  Loss:0.162  Accuracy:0.96,0.92,0.96,0.96  Learning_rate:0.0003
# Iter:3440  Loss:0.153  Accuracy:1.00,0.96,0.92,0.92  Learning_rate:0.0003
# Iter:3460  Loss:0.171  Accuracy:0.96,0.96,0.84,1.00  Learning_rate:0.0003
# Iter:3480  Loss:0.137  Accuracy:0.96,0.96,1.00,1.00  Learning_rate:0.0003
# Iter:3500  Loss:0.224  Accuracy:1.00,0.92,0.88,0.92  Learning_rate:0.0003
# Iter:3520  Loss:0.125  Accuracy:1.00,0.96,0.96,0.92  Learning_rate:0.0003
# Iter:3540  Loss:0.136  Accuracy:1.00,0.92,0.96,1.00  Learning_rate:0.0003
# Iter:3560  Loss:0.209  Accuracy:0.88,1.00,0.92,0.96  Learning_rate:0.0003
# Iter:3580  Loss:0.159  Accuracy:0.88,0.92,1.00,1.00  Learning_rate:0.0003
# Iter:3600  Loss:0.212  Accuracy:1.00,1.00,0.84,0.88  Learning_rate:0.0003
# Iter:3620  Loss:0.198  Accuracy:0.92,1.00,0.88,0.96  Learning_rate:0.0003
# Iter:3640  Loss:0.105  Accuracy:1.00,1.00,0.92,0.96  Learning_rate:0.0003
# Iter:3660  Loss:0.159  Accuracy:1.00,0.84,0.96,1.00  Learning_rate:0.0003
# Iter:3680  Loss:0.208  Accuracy:0.96,0.96,0.88,0.92  Learning_rate:0.0003
# Iter:3700  Loss:0.168  Accuracy:0.92,0.92,0.92,1.00  Learning_rate:0.0003
# Iter:3720  Loss:0.136  Accuracy:0.96,0.92,0.92,0.96  Learning_rate:0.0003
# Iter:3740  Loss:0.078  Accuracy:0.96,1.00,1.00,0.92  Learning_rate:0.0003
# Iter:3760  Loss:0.185  Accuracy:0.92,0.92,0.96,0.92  Learning_rate:0.0003
# Iter:3780  Loss:0.153  Accuracy:0.96,0.96,0.96,1.00  Learning_rate:0.0003
# Iter:3800  Loss:0.271  Accuracy:0.96,0.80,0.88,1.00  Learning_rate:0.0003
# Iter:3820  Loss:0.162  Accuracy:1.00,0.92,0.88,0.96  Learning_rate:0.0003
# Iter:3840  Loss:0.180  Accuracy:0.92,0.88,0.96,0.96  Learning_rate:0.0003
# Iter:3860  Loss:0.099  Accuracy:0.96,1.00,0.96,1.00  Learning_rate:0.0003
# Iter:3880  Loss:0.285  Accuracy:0.96,0.84,0.84,0.96  Learning_rate:0.0003
# Iter:3900  Loss:0.217  Accuracy:0.92,0.92,0.92,0.92  Learning_rate:0.0003
# Iter:3920  Loss:0.115  Accuracy:0.92,0.92,0.92,1.00  Learning_rate:0.0003
# Iter:3940  Loss:0.088  Accuracy:0.96,0.96,0.96,1.00  Learning_rate:0.0003
# Iter:3960  Loss:0.104  Accuracy:0.96,0.96,0.96,1.00  Learning_rate:0.0003
# Iter:3980  Loss:0.179  Accuracy:0.96,0.96,0.88,0.96  Learning_rate:0.0003
# Iter:4000  Loss:0.157  Accuracy:1.00,0.96,0.88,0.96  Learning_rate:0.0001
# Iter:4020  Loss:0.156  Accuracy:0.96,0.96,0.88,1.00  Learning_rate:0.0001
# Iter:4040  Loss:0.130  Accuracy:0.92,1.00,0.96,1.00  Learning_rate:0.0001
# Iter:4060  Loss:0.136  Accuracy:1.00,0.92,1.00,0.88  Learning_rate:0.0001
# Iter:4080  Loss:0.149  Accuracy:0.92,0.96,1.00,0.92  Learning_rate:0.0001
# Iter:4100  Loss:0.070  Accuracy:1.00,0.96,0.96,1.00  Learning_rate:0.0001
# Iter:4120  Loss:0.074  Accuracy:0.96,1.00,1.00,0.96  Learning_rate:0.0001
# Iter:4140  Loss:0.127  Accuracy:0.96,0.92,0.96,1.00  Learning_rate:0.0001
# Iter:4160  Loss:0.176  Accuracy:1.00,0.96,0.96,0.88  Learning_rate:0.0001
# Iter:4180  Loss:0.150  Accuracy:0.92,0.96,0.92,1.00  Learning_rate:0.0001
# Iter:4200  Loss:0.101  Accuracy:0.96,0.96,1.00,0.96  Learning_rate:0.0001
# Iter:4220  Loss:0.119  Accuracy:1.00,1.00,0.96,0.96  Learning_rate:0.0001
# Iter:4240  Loss:0.112  Accuracy:0.96,1.00,0.92,0.96  Learning_rate:0.0001
# Iter:4260  Loss:0.089  Accuracy:0.96,0.96,1.00,0.92  Learning_rate:0.0001
# Iter:4280  Loss:0.123  Accuracy:1.00,0.92,0.96,1.00  Learning_rate:0.0001
# Iter:4300  Loss:0.134  Accuracy:1.00,1.00,0.92,0.96  Learning_rate:0.0001
# Iter:4320  Loss:0.086  Accuracy:1.00,1.00,1.00,0.92  Learning_rate:0.0001
# Iter:4340  Loss:0.066  Accuracy:1.00,0.92,1.00,0.96  Learning_rate:0.0001
# Iter:4360  Loss:0.109  Accuracy:1.00,1.00,0.84,1.00  Learning_rate:0.0001
# Iter:4380  Loss:0.106  Accuracy:1.00,0.96,0.96,0.92  Learning_rate:0.0001
# Iter:4400  Loss:0.141  Accuracy:1.00,0.96,1.00,0.88  Learning_rate:0.0001
# Iter:4420  Loss:0.138  Accuracy:0.96,0.96,0.96,1.00  Learning_rate:0.0001
# Iter:4440  Loss:0.059  Accuracy:1.00,0.96,1.00,0.96  Learning_rate:0.0001
# Iter:4460  Loss:0.100  Accuracy:1.00,0.96,0.96,0.96  Learning_rate:0.0001
# Iter:4480  Loss:0.067  Accuracy:1.00,0.92,0.96,1.00  Learning_rate:0.0001
# Iter:4500  Loss:0.116  Accuracy:0.92,1.00,0.84,1.00  Learning_rate:0.0001
# Iter:4520  Loss:0.155  Accuracy:0.96,0.92,0.88,0.96  Learning_rate:0.0001
# Iter:4540  Loss:0.212  Accuracy:0.96,0.92,0.92,0.92  Learning_rate:0.0001
# Iter:4560  Loss:0.152  Accuracy:0.96,1.00,0.88,0.96  Learning_rate:0.0001
# Iter:4580  Loss:0.075  Accuracy:0.96,0.96,0.92,1.00  Learning_rate:0.0001
# Iter:4600  Loss:0.092  Accuracy:1.00,1.00,0.92,1.00  Learning_rate:0.0001
# Iter:4620  Loss:0.087  Accuracy:0.92,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4640  Loss:0.050  Accuracy:0.96,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4660  Loss:0.085  Accuracy:0.96,0.96,0.96,0.96  Learning_rate:0.0001
# Iter:4680  Loss:0.069  Accuracy:0.96,0.96,0.96,1.00  Learning_rate:0.0001
# Iter:4700  Loss:0.065  Accuracy:0.96,1.00,0.96,1.00  Learning_rate:0.0001
# Iter:4720  Loss:0.074  Accuracy:0.96,1.00,0.92,1.00  Learning_rate:0.0001
# Iter:4740  Loss:0.104  Accuracy:0.96,1.00,0.96,0.92  Learning_rate:0.0001
# Iter:4760  Loss:0.057  Accuracy:1.00,1.00,0.96,1.00  Learning_rate:0.0001
# Iter:4780  Loss:0.129  Accuracy:0.96,1.00,0.92,0.92  Learning_rate:0.0001
# Iter:4800  Loss:0.135  Accuracy:1.00,0.92,0.96,0.96  Learning_rate:0.0001
# Iter:4820  Loss:0.088  Accuracy:0.96,0.96,1.00,1.00  Learning_rate:0.0001
# Iter:4840  Loss:0.066  Accuracy:0.96,1.00,1.00,0.96  Learning_rate:0.0001
# Iter:4860  Loss:0.054  Accuracy:0.96,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4880  Loss:0.086  Accuracy:1.00,1.00,0.92,1.00  Learning_rate:0.0001
# Iter:4900  Loss:0.121  Accuracy:1.00,0.92,0.96,1.00  Learning_rate:0.0001
# Iter:4920  Loss:0.056  Accuracy:0.96,1.00,0.92,1.00  Learning_rate:0.0001
# Iter:4940  Loss:0.058  Accuracy:1.00,1.00,1.00,0.96  Learning_rate:0.0001
# Iter:4960  Loss:0.070  Accuracy:0.92,0.92,1.00,1.00  Learning_rate:0.0001
# Iter:4980  Loss:0.135  Accuracy:1.00,0.84,0.84,0.96  Learning_rate:0.0001
# Iter:5000  Loss:0.164  Accuracy:0.92,0.96,0.96,0.92  Learning_rate:0.0001
# Iter:5020  Loss:0.086  Accuracy:0.96,0.96,1.00,1.00  Learning_rate:0.0001
# Iter:5040  Loss:0.147  Accuracy:1.00,0.96,0.96,0.96  Learning_rate:0.0001
# Iter:5060  Loss:0.202  Accuracy:0.96,0.88,0.88,1.00  Learning_rate:0.0001
# Iter:5080  Loss:0.077  Accuracy:0.96,1.00,1.00,0.96  Learning_rate:0.0001
# Iter:5100  Loss:0.124  Accuracy:0.96,0.96,0.96,0.96  Learning_rate:0.0001
# Iter:5120  Loss:0.134  Accuracy:0.96,0.92,1.00,0.96  Learning_rate:0.0001
# Iter:5140  Loss:0.135  Accuracy:1.00,0.88,0.84,1.00  Learning_rate:0.0001
# Iter:5160  Loss:0.114  Accuracy:0.96,0.84,0.96,1.00  Learning_rate:0.0001
# Iter:5180  Loss:0.096  Accuracy:0.96,0.92,0.92,1.00  Learning_rate:0.0001
# Iter:5200  Loss:0.079  Accuracy:1.00,0.92,1.00,0.96  Learning_rate:0.0001
# Iter:5220  Loss:0.079  Accuracy:1.00,0.96,1.00,0.88  Learning_rate:0.0001
# Iter:5240  Loss:0.151  Accuracy:1.00,0.92,0.92,0.88  Learning_rate:0.0001
# Iter:5260  Loss:0.109  Accuracy:0.96,0.92,0.92,1.00  Learning_rate:0.0001
# Iter:5280  Loss:0.090  Accuracy:1.00,0.96,0.96,1.00  Learning_rate:0.0001
# Iter:5300  Loss:0.035  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5320  Loss:0.095  Accuracy:0.96,1.00,1.00,0.96  Learning_rate:0.0001
# Iter:5340  Loss:0.083  Accuracy:0.96,1.00,0.88,1.00  Learning_rate:0.0001
# Iter:5360  Loss:0.120  Accuracy:1.00,0.96,0.96,0.96  Learning_rate:0.0001
# Iter:5380  Loss:0.050  Accuracy:1.00,1.00,1.00,0.96  Learning_rate:0.0001
# Iter:5400  Loss:0.091  Accuracy:1.00,0.96,0.92,1.00  Learning_rate:0.0001
# Iter:5420  Loss:0.173  Accuracy:1.00,0.92,0.96,0.96  Learning_rate:0.0001
# Iter:5440  Loss:0.119  Accuracy:0.88,0.92,1.00,1.00  Learning_rate:0.0001
# Iter:5460  Loss:0.078  Accuracy:1.00,1.00,0.96,1.00  Learning_rate:0.0001
# Iter:5480  Loss:0.114  Accuracy:1.00,0.88,0.88,1.00  Learning_rate:0.0001
# Iter:5500  Loss:0.134  Accuracy:0.96,0.96,0.96,0.92  Learning_rate:0.0001
# Iter:5520  Loss:0.217  Accuracy:0.96,1.00,0.84,0.84  Learning_rate:0.0001
# Iter:5540  Loss:0.066  Accuracy:1.00,1.00,0.96,1.00  Learning_rate:0.0001
# Iter:5560  Loss:0.139  Accuracy:0.92,0.96,1.00,0.92  Learning_rate:0.0001
# Iter:5580  Loss:0.052  Accuracy:1.00,1.00,0.96,1.00  Learning_rate:0.0001
# Iter:5600  Loss:0.065  Accuracy:1.00,0.96,0.96,1.00  Learning_rate:0.0001
# Iter:5620  Loss:0.122  Accuracy:1.00,0.96,0.92,0.96  Learning_rate:0.0001
# Iter:5640  Loss:0.070  Accuracy:1.00,0.96,0.96,0.96  Learning_rate:0.0001
# Iter:5660  Loss:0.039  Accuracy:1.00,1.00,1.00,0.96  Learning_rate:0.0001
# Iter:5680  Loss:0.072  Accuracy:1.00,1.00,0.96,1.00  Learning_rate:0.0001
# Iter:5700  Loss:0.047  Accuracy:1.00,1.00,1.00,0.96  Learning_rate:0.0001
# Iter:5720  Loss:0.081  Accuracy:0.96,0.96,0.96,0.96  Learning_rate:0.0001
# Iter:5740  Loss:0.087  Accuracy:1.00,0.96,0.92,1.00  Learning_rate:0.0001
# Iter:5760  Loss:0.068  Accuracy:1.00,1.00,1.00,0.92  Learning_rate:0.0001
# Iter:5780  Loss:0.066  Accuracy:0.96,1.00,1.00,0.96  Learning_rate:0.0001
# Iter:5800  Loss:0.057  Accuracy:0.96,0.96,0.96,1.00  Learning_rate:0.0001
# Iter:5820  Loss:0.158  Accuracy:0.96,0.88,1.00,0.96  Learning_rate:0.0001
# Iter:5840  Loss:0.038  Accuracy:1.00,1.00,0.96,1.00  Learning_rate:0.0001
# Iter:5860  Loss:0.076  Accuracy:0.96,0.96,1.00,0.96  Learning_rate:0.0001
# Iter:5880  Loss:0.084  Accuracy:1.00,0.96,0.96,0.96  Learning_rate:0.0001
# Iter:5900  Loss:0.117  Accuracy:1.00,0.92,0.92,1.00  Learning_rate:0.0001
# Iter:5920  Loss:0.165  Accuracy:0.92,0.96,0.88,1.00  Learning_rate:0.0001
# Iter:5940  Loss:0.038  Accuracy:1.00,0.96,1.00,1.00  Learning_rate:0.0001
# Iter:5960  Loss:0.115  Accuracy:1.00,0.96,0.92,0.92  Learning_rate:0.0001
# Iter:5980  Loss:0.108  Accuracy:0.96,0.92,0.96,0.96  Learning_rate:0.0001
# Iter:6000  Loss:0.075  Accuracy:1.00,0.96,0.96,1.00  Learning_rate:0.0000
