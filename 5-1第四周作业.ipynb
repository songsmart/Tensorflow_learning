# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

#载入数据集
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)

#每个批次的大小
batch_size = 100
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])
keep_prob = tf.placeholder(tf.float32)
lr = tf.Variable(0.001, dtype = tf.float32)

#创建一个简单的神经网络
W1 = tf.Variable(tf.truncated_normal([784,500],stddev=0.1))
b1 = tf.Variable(tf.zeros([500])+0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop = tf.nn.dropout(L1,keep_prob )

W2 = tf.Variable(tf.truncated_normal([500,300],stddev=0.1))
b2 = tf.Variable(tf.zeros([300])+0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop = tf.nn.dropout(L2,keep_prob )

W3 = tf.Variable(tf.truncated_normal([300,10],stddev=0.1))
b3 = tf.Variable(tf.zeros([10])+0.1)
prediction = tf.nn.tanh(tf.matmul(L2_drop,W3)+b3)

#二次代价函数
# loss = tf.reduce_mean(tf.square(y-prediction))
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = y , logits = prediction))
#使用梯度下降法
# train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)
train_step = tf.train.AdamOptimizer(lr).minimize(loss)


#初始化变量
init = tf.global_variables_initializer()

#结果存放在一个布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))#argmax返回一维张量中最大值
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(51):
        sess.run(tf.assign(lr,0.001 * (0.95 ** epoch)))
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict = {x:batch_xs,y:batch_ys,keep_prob:0.7})
        
        learning_rate = sess.run(lr)
        test_acc = sess.run(accuracy,feed_dict = {x:mnist.test.images,y:mnist.test.labels,keep_prob:1.0})
        train_acc = sess.run(accuracy,feed_dict = {x:mnist.train.images,y:mnist.train.labels,keep_prob:1.0})
        print("Iter" + str(epoch)+",Testing Accuaracy"+str(test_acc)+",Training Accuracy"+str(train_acc)+",Learning Rate" +str(learning_rate))
    sess.close()
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter0,Testing Accuaracy0.938,Training Accuracy0.93903637,Learning Rate0.001
# Iter1,Testing Accuaracy0.9496,Training Accuracy0.95403636,Learning Rate0.00095
# Iter2,Testing Accuaracy0.9562,Training Accuracy0.9623273,Learning Rate0.0009025
# Iter3,Testing Accuaracy0.9607,Training Accuracy0.9668546,Learning Rate0.000857375
# Iter4,Testing Accuaracy0.9637,Training Accuracy0.9689091,Learning Rate0.00081450626
# Iter5,Testing Accuaracy0.9672,Training Accuracy0.97401816,Learning Rate0.0007737809
# Iter6,Testing Accuaracy0.9695,Training Accuracy0.9762545,Learning Rate0.0007350919
# Iter7,Testing Accuaracy0.9695,Training Accuracy0.9778182,Learning Rate0.0006983373
# Iter8,Testing Accuaracy0.9711,Training Accuracy0.9789636,Learning Rate0.0006634204
# Iter9,Testing Accuaracy0.9721,Training Accuracy0.9813455,Learning Rate0.0006302494
# Iter10,Testing Accuaracy0.9728,Training Accuracy0.98283637,Learning Rate0.0005987369
# Iter11,Testing Accuaracy0.9735,Training Accuracy0.9841091,Learning Rate0.0005688001
# Iter12,Testing Accuaracy0.9744,Training Accuracy0.98474544,Learning Rate0.0005403601
# Iter13,Testing Accuaracy0.974,Training Accuracy0.98565453,Learning Rate0.0005133421
# Iter14,Testing Accuaracy0.975,Training Accuracy0.98676366,Learning Rate0.000487675
# Iter15,Testing Accuaracy0.9767,Training Accuracy0.9876,Learning Rate0.00046329122
# Iter16,Testing Accuaracy0.9769,Training Accuracy0.98809093,Learning Rate0.00044012666
# Iter17,Testing Accuaracy0.9756,Training Accuracy0.9881273,Learning Rate0.00041812033
# Iter18,Testing Accuaracy0.9764,Training Accuracy0.9886,Learning Rate0.00039721432
# Iter19,Testing Accuaracy0.977,Training Accuracy0.9886364,Learning Rate0.0003773536
# Iter20,Testing Accuaracy0.9775,Training Accuracy0.98974544,Learning Rate0.00035848594
# Iter21,Testing Accuaracy0.978,Training Accuracy0.9904909,Learning Rate0.00034056162
# Iter22,Testing Accuaracy0.9769,Training Accuracy0.9906,Learning Rate0.00032353355
# Iter23,Testing Accuaracy0.9787,Training Accuracy0.9908364,Learning Rate0.00030735688
# Iter24,Testing Accuaracy0.9767,Training Accuracy0.9912182,Learning Rate0.000291989
# Iter25,Testing Accuaracy0.9793,Training Accuracy0.9914182,Learning Rate0.00027738957
# Iter26,Testing Accuaracy0.9783,Training Accuracy0.99183637,Learning Rate0.0002635201
# Iter27,Testing Accuaracy0.9787,Training Accuracy0.99227273,Learning Rate0.00025034408
# Iter28,Testing Accuaracy0.979,Training Accuracy0.9926,Learning Rate0.00023782688
# Iter29,Testing Accuaracy0.9786,Training Accuracy0.9926364,Learning Rate0.00022593554
# Iter30,Testing Accuaracy0.9787,Training Accuracy0.9928909,Learning Rate0.00021463877
# Iter31,Testing Accuaracy0.9796,Training Accuracy0.99307275,Learning Rate0.00020390682
# Iter32,Testing Accuaracy0.9788,Training Accuracy0.9932,Learning Rate0.00019371149
# Iter33,Testing Accuaracy0.9794,Training Accuracy0.99323636,Learning Rate0.0001840259
# Iter34,Testing Accuaracy0.9785,Training Accuracy0.9934545,Learning Rate0.00017482461
# Iter35,Testing Accuaracy0.9801,Training Accuracy0.9935455,Learning Rate0.00016608338
# Iter36,Testing Accuaracy0.9797,Training Accuracy0.99396366,Learning Rate0.00015777921
# Iter37,Testing Accuaracy0.9803,Training Accuracy0.9941091,Learning Rate0.00014989026
# Iter38,Testing Accuaracy0.98,Training Accuracy0.99430907,Learning Rate0.00014239574
# Iter39,Testing Accuaracy0.9807,Training Accuracy0.9942,Learning Rate0.00013527596
# Iter40,Testing Accuaracy0.9807,Training Accuracy0.9942727,Learning Rate0.00012851215
# Iter41,Testing Accuaracy0.9802,Training Accuracy0.99454546,Learning Rate0.00012208655
# Iter42,Testing Accuaracy0.9805,Training Accuracy0.9946909,Learning Rate0.00011598222
# Iter43,Testing Accuaracy0.9804,Training Accuracy0.99472725,Learning Rate0.00011018311
# Iter44,Testing Accuaracy0.9803,Training Accuracy0.9948364,Learning Rate0.000104673956
# Iter45,Testing Accuaracy0.9805,Training Accuracy0.9950182,Learning Rate9.944026e-05
# Iter46,Testing Accuaracy0.9809,Training Accuracy0.9950727,Learning Rate9.446825e-05
# Iter47,Testing Accuaracy0.9801,Training Accuracy0.9950727,Learning Rate8.974483e-05
# Iter48,Testing Accuaracy0.9805,Training Accuracy0.99514544,Learning Rate8.525759e-05
# Iter49,Testing Accuaracy0.9806,Training Accuracy0.9951091,Learning Rate8.099471e-05
# Iter50,Testing Accuaracy0.9806,Training Accuracy0.99503636,Learning Rate7.6944976e-05
